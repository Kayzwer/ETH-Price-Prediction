# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('ETH_USD_2015-08-09_2021-01-16-CoinDesk.csv')
df['Date'] = pd.to_datetime(df['Date'], format=('%Y-%m-%d'))

# %%
df.drop(['Currency'], axis=1, inplace=True)
df.head()
# Out:
#         Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0 2015-08-09             0.909046        1.749289        1.916540
# 1 2015-08-10             0.692321        0.909046        0.909046
# 2 2015-08-11             0.668067        0.692321        0.692321
# 3 2015-08-12             0.850151        0.668067        1.148621
# 4 2015-08-13             1.266023        0.850151        1.266023
#
#    24h Low (USD)
# 0       0.794497
# 1       0.692321
# 2       0.654331
# 3       0.668067
# 4       0.850151

# %%
plt.figure(figsize=(24,11))
plt.plot(df['Closing Price (USD)'], c='r')
plt.title('Close Price from 2015/8 - 2021/1', fontsize=21)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price', fontsize=18)
plt.tight_layout()
plt.show()

# %%
data = df.filter(['Closing Price (USD)'])
dataset = data.values
training_data_len = math.ceil(len(dataset) * .9)
training_data_len
# Out:
# 1781

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[3.42154252e-04],
#        [1.87877602e-04],
#        [1.70612285e-04],
#        ...,
#        [7.94433589e-01],
#        [8.37792754e-01],
#        [8.33558387e-01]])

# %%
train_data = scaled_data[0:training_data_len, :]

x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.00034215, 0.00018788, 0.00017061, 0.00030023, 0.00059627,
#        0.0010842 , 0.00082776, 0.00090072, 0.00070819, 0.00054898,
#        0.00053705, 0.0006059 , 0.00072543, 0.00066784, 0.00063531,
#        0.00067359, 0.00055603, 0.00044575, 0.00053688, 0.00051723,
#        0.00054027, 0.00049942, 0.00058833, 0.00064466, 0.00064003,
#        0.00061611, 0.00060439, 0.00060113, 0.00065626, 0.00060897,
#        0.00060187, 0.0005686 , 0.00055932, 0.00050215, 0.00040446,
#        0.00044813, 0.0003666 , 0.00033285, 0.00037407, 0.00034199,
#        0.0003061 , 0.00030176, 0.00031872, 0.00039167, 0.0003383 ,
#        0.00033737, 0.00032316, 0.00028101, 0.00020631, 0.00025507,
#        0.00017478, 0.000113  , 0.00016725, 0.00022425, 0.00018149,
#        0.00017453, 0.00019647, 0.00017538, 0.00013064, 0.00014163])]
# [0.00012046214107390581]
#
# [array([0.00034215, 0.00018788, 0.00017061, 0.00030023, 0.00059627,
#        0.0010842 , 0.00082776, 0.00090072, 0.00070819, 0.00054898,
# ...

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (1721, 60, 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, batch_size=1, epochs=5)
# Out:
# Epoch 1/5
# 1721/1721 [==============================] - 49s 28ms/step - loss: 4.1141e-04
# Epoch 2/5
# 1721/1721 [==============================] - 48s 28ms/step - loss: 4.8816e-04
# Epoch 3/5
# 1721/1721 [==============================] - 48s 28ms/step - loss: 4.4482e-04
# Epoch 4/5
# 1721/1721 [==============================] - 47s 27ms/step - loss: 4.0539e-04
# Epoch 5/5
# 1721/1721 [==============================] - 47s 27ms/step - loss: 5.2118e-04

# %%
test_data = scaled_data[training_data_len - 60: , :]

x_test = []
y_test = dataset[training_data_len: , :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# %%
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# %%
rmse = np.sqrt(np.mean(predictions - y_test) ** 2)
rmse
# Out:
# 33.40750263391216

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions

plt.figure(figsize=(24,11))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Closing Price', fontsize=18)
plt.plot(train['Closing Price (USD)'])
plt.plot(valid[['Closing Price (USD)', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# C:\Users\Asus\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import joblib
joblib.dump(model, 'ETH predictor')
# Out:
# ['ETH predictor']
